# %%
import pandas as pd
import os
import pickle

# %%
with open("../custom_components/trained_models/bert_solo/training_stats.pickle", 'rb') as f:
    data = pickle.load(f)
    bert_df = pd.DataFrame(data)
with open("../custom_components/trained_models/basic_transformer/training_stats.pickle", 'rb') as f:
    data = pickle.load(f)
    base_df = pd.DataFrame(data)
with open("../custom_components/trained_models/student_transformer/training_stats_00.pickle", 'rb') as f:
    data = pickle.load(f)
    student_00_df = pd.DataFrame(data)
with open("../custom_components/trained_models/student_transformer/training_stats_05.pickle", 'rb') as f:
    data = pickle.load(f)
    student_05_df = pd.DataFrame(data)
with open("../custom_components/trained_models/student_transformer/training_stats_10.pickle", 'rb') as f:
    data = pickle.load(f)
    student_10_df = pd.DataFrame(data)
with open("../custom_components/trained_models/student_transformer/training_stats_30.pickle", 'rb') as f:
    data = pickle.load(f)
    student_30_df = pd.DataFrame(data)
with open("../custom_components/trained_models/student_transformer/training_stats_50.pickle", 'rb') as f:
    data = pickle.load(f)
    student_50_df = pd.DataFrame(data)

# %%
bert_df
bert_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"], title="Intent Classification with BERT")
# Out:
# <AxesSubplot:title={'center':'Intent Classification with BERT'}, xlabel='epoch'>

# %%
base_df
base_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"], title="Intent Classification, Basic Transformer")
# Out:
# <AxesSubplot:title={'center':'Intent Classification, Basic Transformer'}, xlabel='epoch'>

# %%
student_00_df
student_00_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"], title="Intent Classification, Student Transformer (0%)")
# Out:
# <AxesSubplot:title={'center':'Intent Classification, Student Transformer (0%)'}, xlabel='epoch'>

# %%
student_05_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"], title="Intent Classification, Student Transformer (5%)")
# Out:
# <AxesSubplot:title={'center':'Intent Classification, Student Transformer (5%)'}, xlabel='epoch'>

# %%
student_10_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"], title="Intent Classification, Student Transformer (10%)")
# Out:
# <AxesSubplot:title={'center':'Intent Classification, Student Transformer (10%)'}, xlabel='epoch'>

# %%
student_30_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"])
# Out:
# <AxesSubplot:xlabel='epoch'>

# %%
student_50_df.plot(x="epoch", y=["Training Loss", "Valid. Loss"])
# Out:
# <AxesSubplot:xlabel='epoch'>
